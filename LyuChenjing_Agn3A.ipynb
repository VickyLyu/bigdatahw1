# %% [markdown]
# # Access web page table using Pandas

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
urlString='https://www.treasury.gov/resource-center/data-chart-center/interest-rates/Pages/TextView.aspx?data=yield'
dfs= pd.read_html(urlString)
print(len(dfs))
# Out:
# 8

# %%
dfs[1]
# Out:
#        Date  1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  \
# 0  02/03/20  1.56  1.57  1.57  1.56  1.46  1.36  1.34  1.35  1.45   1.54
# 1  02/04/20  1.55  1.57  1.57  1.57  1.48  1.41  1.40  1.42  1.52   1.61
# 2  02/05/20  1.55  1.56  1.57  1.57  1.49  1.44  1.43  1.46  1.57   1.66
# 3  02/06/20  1.59  1.59  1.57  1.58  1.51  1.44  1.43  1.45  1.56   1.65
# 4  02/07/20  1.57  1.58  1.56  1.57  1.49  1.41  1.39  1.41  1.51   1.59
# 5  02/10/20  1.58  1.58  1.58  1.58  1.45  1.37  1.36  1.38  1.47   1.56
#
#    20 yr  30 yr
# 0   1.84   2.01
# 1   1.91   2.08
# 2   1.97   2.14
# 3   1.94   2.11
# 4   1.89   2.05
# 5   1.87   2.03

# %%
interest_rate=dfs[1]
interest_rate
# Out:
#        Date  1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  \
# 0  02/03/20  1.56  1.57  1.57  1.56  1.46  1.36  1.34  1.35  1.45   1.54
# 1  02/04/20  1.55  1.57  1.57  1.57  1.48  1.41  1.40  1.42  1.52   1.61
# 2  02/05/20  1.55  1.56  1.57  1.57  1.49  1.44  1.43  1.46  1.57   1.66
# 3  02/06/20  1.59  1.59  1.57  1.58  1.51  1.44  1.43  1.45  1.56   1.65
# 4  02/07/20  1.57  1.58  1.56  1.57  1.49  1.41  1.39  1.41  1.51   1.59
# 5  02/10/20  1.58  1.58  1.58  1.58  1.45  1.37  1.36  1.38  1.47   1.56
#
#    20 yr  30 yr
# 0   1.84   2.01
# 1   1.91   2.08
# 2   1.97   2.14
# 3   1.94   2.11
# 4   1.89   2.05
# 5   1.87   2.03

# %%
interest_rate.set_index(["Date"], inplace=True)
interest_rate
# Out:
#           1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  20 yr  \
# Date
# 02/03/20  1.56  1.57  1.57  1.56  1.46  1.36  1.34  1.35  1.45   1.54   1.84
# 02/04/20  1.55  1.57  1.57  1.57  1.48  1.41  1.40  1.42  1.52   1.61   1.91
# 02/05/20  1.55  1.56  1.57  1.57  1.49  1.44  1.43  1.46  1.57   1.66   1.97
# 02/06/20  1.59  1.59  1.57  1.58  1.51  1.44  1.43  1.45  1.56   1.65   1.94
# 02/07/20  1.57  1.58  1.56  1.57  1.49  1.41  1.39  1.41  1.51   1.59   1.89
# 02/10/20  1.58  1.58  1.58  1.58  1.45  1.37  1.36  1.38  1.47   1.56   1.87
#
#           30 yr
# Date
# 02/03/20   2.01
# 02/04/20   2.08
# 02/05/20   2.14
# 02/06/20   2.11
# 02/07/20   2.05
# 02/10/20   2.03

# %%
import numpy as np
row_data=np.array(interest_rate)
row_1=row_data.tolist()
r1= row_1[0]
r1
# Out:
# [1.56, 1.57, 1.57, 1.56, 1.46, 1.36, 1.34, 1.35, 1.45, 1.54, 1.84, 2.01]

# %%
import numpy as np
row_data=np.array(interest_rate)
row_1=row_data.tolist()
rlatest= row_1[-1]
rlatest
# Out:
# [1.58, 1.58, 1.58, 1.58, 1.45, 1.37, 1.36, 1.38, 1.47, 1.56, 1.87, 2.03]

# %%
import matplotlib.pyplot as plt
years=[1/12,2/12,3/12,6/12,1,2,3,5,7,10,20,30]
yields=rlatest
plt.scatter(years,yields)
plt.show()
